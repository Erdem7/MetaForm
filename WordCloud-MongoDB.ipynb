# %%
import pandas as pd
from pymongo import MongoClient

from os import path
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import matplotlib.pyplot as plt

# %%
client = MongoClient("mongodb://localhost:27017")
db = client.example

# %%
collection_conn = db['data5']
collection_cursor = collection_conn.find()
collection_pandas_df = pd.DataFrame(list(collection_cursor))

# %%
texts=collection_pandas_df.texts[0]

# %%
print(texts)
# Out:
# Türkiye'nin katıldığı savaşlar listesi

# %%
wordcloud = WordCloud().generate(texts)

# %%
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()
